# %%
from src.dados_cvm.client import CVMClient
from src.dados_cvm.endpoints import DocType

client = CVMClient()
print(client.path_data_dir.absolute())
# Out:
# c:\Users\141627\Desktop\Arquivos\Projeto\teste\CVM\arquivos

# %%
df =client.get_zip(ano=2024, doc_type=DocType.DFP, extrair=True)

# %%
from src.dados_cvm.endpoints import StatementType, Scope, DocType
df_itr_con = client.load_statement(ano=2024, statement=StatementType.BPA, scope=Scope.CON, doc_type=DocType.ITR)

# %%
from src.dados_cvm.balanco import Balanco

# %%
bl = Balanco(df_itr_con)

# %%
df_bl =bl.filtrar_por_cd_cvm(1023).filtrar_por_exercicio('ÚLTIMO').get_dataframe()
df_bl

# %%
df_bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 1 to 245
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CNPJ_CIA       123 non-null    object
#  1   DT_REFER       123 non-null    object
#  2   VERSAO         123 non-null    int64
#  3   DENOM_CIA      123 non-null    object
#  4   CD_CVM         123 non-null    int64
#  5   GRUPO_DFP      123 non-null    object
#  6   MOEDA          123 non-null    object
#  7   ESCALA_MOEDA   123 non-null    object
#  8   ORDEM_EXERC    123 non-null    object
#  9   DT_FIM_EXERC   123 non-null    object
#  10  CD_CONTA       123 non-null    object
#  11  DS_CONTA       123 non-null    object
#  12  VL_CONTA       123 non-null    float64
#  13  ST_CONTA_FIXA  123 non-null    object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 14.4+ KB
